# %% [markdown]
# # A full business solution
#
# ## Now we will take our project from Day 1 to the next level
#
# ### BUSINESS CHALLENGE:
#
# Create a product that builds a Brochure for a company to be used for prospective clients, investors and potential recruits.
#
# We will be provided a company name and their primary website.
#
# See the end of this notebook for examples of real-world business applications.
#
# And remember: I'm always available if you have problems or ideas! Please do reach out.

# %%
# imports
# If these fail, please check you're running from an 'activated' environment with (llms) in the command prompt

import os
import requests
import json
from typing import List
from dotenv import load_dotenv
from bs4 import BeautifulSoup
from IPython.display import Markdown, display, update_display
from openai import OpenAI

# %%
# Initialize and constants

load_dotenv(override=True)
api_key = os.getenv('OPENAI_API_KEY')

if api_key and api_key.startswith('sk-proj-') and len(api_key)>10:
    print("API key looks good so far")
else:
    print("There might be a problem with your API key? Please visit the troubleshooting notebook!")
    
MODEL = 'gpt-4o-mini'
openai = OpenAI()
# Out:
# API key looks good so far

# %%
# A class to represent a Webpage

# Some websites need you to use proper headers when fetching them:
headers = {
 "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/117.0.0.0 Safari/537.36"
}

class Website:
    """
    A utility class to represent a Website that we have scraped, now with links
    """

    def __init__(self, url):
        self.url = url
        response = requests.get(url, headers=headers)
        self.body = response.content
        soup = BeautifulSoup(self.body, 'html.parser')
        self.title = soup.title.string if soup.title else "No title found"
        if soup.body:
            for irrelevant in soup.body(["script", "style", "img", "input"]):
                irrelevant.decompose()
            self.text = soup.body.get_text(separator="\n", strip=True)
        else:
            self.text = ""
        links = [link.get('href') for link in soup.find_all('a')]
        self.links = [link for link in links if link]

    def get_contents(self):
        return f"Webpage Title:\n{self.title}\nWebpage Contents:\n{self.text}\n\n"

# %%
ed = Website("https://edwarddonner.com")
ed.links
# Out:
# ['https://edwarddonner.com/',
#  'https://edwarddonner.com/connect-four/',
#  'https://edwarddonner.com/outsmart/',
#  'https://edwarddonner.com/about-me-and-about-nebula/',
#  'https://edwarddonner.com/posts/',
#  'https://edwarddonner.com/',
#  'https://news.ycombinator.com',
#  'https://nebula.io/?utm_source=ed&utm_medium=referral',
#  'https://www.prnewswire.com/news-releases/wynden-stark-group-acquires-nyc-venture-backed-tech-startup-untapt-301269512.html',
#  'https://patents.google.com/patent/US20210049536A1/',
#  'https://www.linkedin.com/in/eddonner/',
#  'https://edwarddonner.com/2025/04/21/the-complete-agentic-ai-engineering-course/',
#  'https://edwarddonner.com/2025/04/21/the-complete-agentic-ai-engineering-course/',
#  'https://edwarddonner.com/2025/01/23/llm-workshop-hands-on-with-agents-resources/',
#  'https://edwarddonner.com/2025/01/23/llm-workshop-hands-on-with-agents-resources/',
#  'https://edwarddonner.com/2024/12/21/llm-resources-superdatascience/',
#  'https://edwarddonner.com/2024/12/21/llm-resources-superdatascience/',
#  'https://edwarddonner.com/2024/11/13/llm-engineering-resources/',
#  'https://edwarddonner.com/2024/11/13/llm-engineering-resources/',
#  'https://edwarddonner.com/',
#  'https://edwarddonner.com/connect-four/',
#  'https://edwarddonner.com/outsmart/',
#  'https://edwarddonner.com/about-me-and-about-nebula/',
#  'https://edwarddonner.com/posts/',
#  'mailto:hello@mygroovydomain.com',
#  'https://www.linkedin.com/in/eddonner/',
#  'https://twitter.com/edwarddonner',
#  'https://www.facebook.com/edward.donner.52']

# %% [markdown]
# ## First step: Have GPT-4o-mini figure out which links are relevant
#
# ### Use a call to gpt-4o-mini to read the links on a webpage, and respond in structured JSON.
# It should decide which links are relevant, and replace relative links such as "/about" with "https://company.com/about".
# We will use "one shot prompting" in which we provide an example of how it should respond in the prompt.
#
# This is an excellent use case for an LLM, because it requires nuanced understanding. Imagine trying to code this without LLMs by parsing and analyzing the webpage - it would be very hard!
#
# Sidenote: there is a more advanced technique called "Structured Outputs" in which we require the model to respond according to a spec. We cover this technique in Week 8 during our autonomous Agentic AI project.

# %%
link_system_prompt = "You are provided with a list of links found on a webpage. \
You are able to decide which of the links would be most relevant to include in a brochure about the company, \
such as links to an About page, or a Company page, or Careers/Jobs pages.\n"
link_system_prompt += "You should respond in JSON as in this example:"
link_system_prompt += """
{
    "links": [
        {"type": "about page", "url": "https://full.url/goes/here/about"},
        {"type": "careers page": "url": "https://another.full.url/careers"}
    ]
}
"""

# %%
print(link_system_prompt)
# Out:
# You are provided with a list of links found on a webpage. You are able to decide which of the links would be most relevant to include in a brochure about the company, such as links to an About page, or a Company page, or Careers/Jobs pages.
# You should respond in JSON as in this example:
# {
#     "links": [
#         {"type": "about page", "url": "https://full.url/goes/here/about"},
#         {"type": "careers page": "url": "https://another.full.url/careers"}
#     ]
# }

# %%
def get_links_user_prompt(website):
    user_prompt = f"Here is the list of links on the website of {website.url} - "
    user_prompt += "please decide which of these are relevant web links for a brochure about the company, respond with the full https URL in JSON format. \
Do not include Terms of Service, Privacy, email links.\n"
    user_prompt += "Links (some might be relative links):\n"
    user_prompt += "\n".join(website.links)
    return user_prompt

# %%
print(get_links_user_prompt(ed))
# Out:
# Here is the list of links on the website of https://edwarddonner.com - please decide which of these are relevant web links for a brochure about the company, respond with the full https URL in JSON format. Do not include Terms of Service, Privacy, email links.
# Links (some might be relative links):
# https://edwarddonner.com/
# https://edwarddonner.com/connect-four/
# https://edwarddonner.com/outsmart/
# https://edwarddonner.com/about-me-and-about-nebula/
# https://edwarddonner.com/posts/
# https://edwarddonner.com/
# https://news.ycombinator.com
# https://nebula.io/?utm_source=ed&utm_medium=referral
# https://www.prnewswire.com/news-releases/wynden-stark-group-acquires-nyc-venture-backed-tech-startup-untapt-301269512.html
# https://patents.google.com/patent/US20210049536A1/
# https://www.linkedin.com/in/eddonner/
# https://edwarddonner.com/2025/04/21/the-complete-agentic-ai-engineering-course/
# https://edwarddonner.com/2025/04/21/the-complete-agentic-ai-engineering-course/
# https://edwarddonner.com/2025/01/23/llm-workshop-hands-on-with-agents-resources/
# https://edwarddonner.com/2025/01/23/llm-workshop-hands-on-with-agents-resources/
# https://edwarddonner.com/2024/12/21/llm-resources-superdatascience/
# https://edwarddonner.com/2024/12/21/llm-resources-superdatascience/
# https://edwarddonner.com/2024/11/13/llm-engineering-resources/
# https://edwarddonner.com/2024/11/13/llm-engineering-resources/
# https://edwarddonner.com/
# https://edwarddonner.com/connect-four/
# https://edwarddonner.com/outsmart/
# https://edwarddonner.com/about-me-and-about-nebula/
# https://edwarddonner.com/posts/
# mailto:hello@mygroovydomain.com
# https://www.linkedin.com/in/eddonner/
# https://twitter.com/edwarddonner
# https://www.facebook.com/edward.donner.52

# %%
def get_links(url):
    website = Website(url)
    response = openai.chat.completions.create(
        model=MODEL,
        messages=[
            {"role": "system", "content": link_system_prompt},
            {"role": "user", "content": get_links_user_prompt(website)}
      ],
        response_format={"type": "json_object"}
    )
    result = response.choices[0].message.content
    return json.loads(result)

# %%
# Anthropic has made their site harder to scrape, so I'm using HuggingFace..

huggingface = Website("https://huggingface.co")
huggingface.links
# Out:
# ['/',
#  '/models',
#  '/datasets',
#  '/spaces',
#  '/posts',
#  '/docs',
#  '/enterprise',
#  '/pricing',
#  '/login',
#  '/join',
#  '/spaces',
#  '/models',
#  '/nvidia/parakeet-tdt-0.6b-v2',
#  '/nari-labs/Dia-1.6B',
#  '/lodestones/Chroma',
#  '/Lightricks/LTX-Video',
#  '/PrimeIntellect/INTELLECT-2',
#  '/models',
#  '/spaces/enzostvs/deepsite',
#  '/spaces/smolagents/computer-agent',
#  '/spaces/ByteDance/DreamO',
#  '/spaces/NihalGazi/FLUX-Pro-Unlimited',
#  '/spaces/Heartsync/NSFW-Uncensored-video',
#  '/spaces',
#  '/datasets/openbmb/Ultra-FineWeb',
#  '/datasets/PrimeIntellect/INTELLECT-2-RL-Dataset',
#  '/datasets/nvidia/OpenCodeReasoning',
#  '/datasets/nvidia/OpenMathReasoning',
#  '/datasets/DMindAI/DMind_Benchmark',
#  '/datasets',
#  '/join',
#  '/pricing#endpoints',
#  '/pricing#spaces',
#  '/pricing',
#  '/enterprise',
#  '/enterprise',
#  '/enterprise',
#  '/enterprise',
#  '/enterprise',
#  '/enterprise',
#  '/enterprise',
#  '/allenai',
#  '/facebook',
#  '/amazon',
#  '/google',
#  '/Intel',
#  '/microsoft',
#  '/grammarly',
#  '/Writer',
#  '/docs/transformers',
#  '/docs/diffusers',
#  '/docs/safetensors',
#  '/docs/huggingface_hub',
#  '/docs/tokenizers',
#  '/docs/trl',
#  '/docs/transformers.js',
#  '/docs/smolagents',
#  '/docs/peft',
#  '/docs/datasets',
#  '/docs/text-generation-inference',
#  '/docs/accelerate',
#  '/models',
#  '/datasets',
#  '/spaces',
#  '/tasks',
#  'https://ui.endpoints.huggingface.co',
#  '/chat',
#  '/huggingface',
#  '/brand',
#  '/terms-of-service',
#  '/privacy',
#  'https://apply.workable.com/huggingface/',
#  'mailto:press@huggingface.co',
#  '/learn',
#  '/docs',
#  '/blog',
#  'https://discuss.huggingface.co',
#  'https://status.huggingface.co/',
#  'https://github.com/huggingface',
#  'https://twitter.com/huggingface',
#  'https://www.linkedin.com/company/huggingface/',
#  '/join/discord']

# %%
get_links("https://anthropic.com")
# Out:
# {'links': [{'type': 'about page', 'url': 'https://www.anthropic.com/company'},
#   {'type': 'careers page', 'url': 'https://www.anthropic.com/careers'},
#   {'type': 'team page', 'url': 'https://www.anthropic.com/team'},
#   {'type': 'enterprise solutions page',
#    'url': 'https://www.anthropic.com/enterprise'},
#   {'type': 'education page', 'url': 'https://www.anthropic.com/education'},
#   {'type': 'customers page', 'url': 'https://www.anthropic.com/customers'},
#   {'type': 'research page', 'url': 'https://www.anthropic.com/research'},
#   {'type': 'news page', 'url': 'https://www.anthropic.com/news'},
#   {'type': 'solutions page', 'url': 'https://www.anthropic.com/solutions'}]}

# %% [markdown]
# ## Second step: make the brochure!
#
# Assemble all the details into another prompt to GPT4-o

# %%
def get_all_details(url):
    result = "Landing page:\n"
    result += Website(url).get_contents()
    links = get_links(url)
    print("Found links:", links)
    for link in links["links"]:
        result += f"\n\n{link['type']}\n"
        result += Website(link["url"]).get_contents()
    return result

# %%
print(get_all_details("https://huggingface.co"))
# Out:
# Found links: {'links': [{'type': 'home page', 'url': 'https://huggingface.co'}, {'type': 'about page', 'url': 'https://huggingface.co/huggingface'}, {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'}, {'type': 'blog page', 'url': 'https://huggingface.co/blog'}, {'type': 'company page', 'url': 'https://www.linkedin.com/company/huggingface/'}, {'type': 'community forum', 'url': 'https://discuss.huggingface.co'}, {'type': 'status page', 'url': 'https://status.huggingface.co/'}]}
# Landing page:
# Webpage Title:
# Hugging Face – The AI community building the future.
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Posts
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# The AI community building the future.
# The platform where the machine learning community collaborates on models, datasets, and applications.
# Explore AI Apps
# or
# Browse 1M+ models
# Trending on
# this week
# Models
# nvidia/parakeet-tdt-0.6b-v2
# Updated
# 1 day ago
# •
# 202k
# •
# 897
# nari-labs/Dia-1.6B
# Updated
# 4 days ago
# •
# 177k
# •
# 2.21k
# lodestones/Chroma
# Updated
# about 20 hours ago
# •
# 561
# Lightricks/LTX-Video
# Updated
# 2 days ago
# •
# 297k
# •
# 1.51k
# PrimeIntellect/INTELLECT-2
# Updated
# 5 days ago
# •
# 609
# •
# 152
# Browse 1M+ models
# Spaces
# Running
# 6.64k
# 6.64k
# DeepSite
# 🐳
# Generate any application with DeepSeek
# Running
# on
# CPU Upgrade
# 650
# 650
# Computer Agent
# 🖥
# Interact with an AI agent to perform web tasks
# Running
# on
# Zero
# 361
# 361
# DreamO
# 🐨
# A Unified Framework for Image Customization
# Running
# 403
# 403
# FLUX Pro Unlimited
# 🔥
# Use the FLUX-Pro model as much as you want.
# Running
# on
# Zero
# 179
# 179
# NSFW Uncensored image to video
# 🎬
# MAX ~60sec Video - AI Limits
# Browse 400k+ applications
# Datasets
# openbmb/Ultra-FineWeb
# Updated
# 9 days ago
# •
# 5.65k
# •
# 63
# PrimeIntellect/INTELLECT-2-RL-Dataset
# Updated
# 5 days ago
# •
# 447
# •
# 41
# nvidia/OpenCodeReasoning
# Updated
# 13 days ago
# •
# 13.6k
# •
# 412
# nvidia/OpenMathReasoning
# Updated
# 8 days ago
# •
# 37.8k
# •
# 232
# DMindAI/DMind_Benchmark
# Updated
# about 1 hour ago
# •
# 2.23k
# •
# 75
# Browse 250k+ datasets
# The Home of Machine Learning
# Create, discover and collaborate on ML better.
# The collaboration platform
# Host and collaborate on unlimited public models, datasets and applications.
# Move faster
# With the HF Open source stack.
# Explore all modalities
# Text, image, video, audio or even 3D.
# Build your portfolio
# Share your work with the world and build your ML profile.
# Sign Up
# Accelerate your ML
# We provide paid Compute and Enterprise solutions.
# Compute
# Deploy on optimized
# Inference Endpoints
# or update your
# Spaces applications
# to a GPU in a few clicks.
# View pricing
# Starting at $0.60/hour for GPU
# Enterprise
# Give your team the most advanced platform to build AI with enterprise-grade security, access controls and
# 			dedicated support.
# Getting started
# Starting at $20/user/month
# Single Sign-On
# Regions
# Priority Support
# Audit Logs
# Resource Groups
# Private Datasets Viewer
# More than 50,000 organizations are using Hugging Face
# Ai2
# Enterprise
# non-profit
# •
# 757 models
# •
# 3.28k followers
# AI at Meta
# Enterprise
# company
# •
# 2.12k models
# •
# 5.98k followers
# Amazon
# company
# •
# 20 models
# •
# 3.16k followers
# Google
# company
# •
# 991 models
# •
# 13.2k followers
# Intel
# company
# •
# 221 models
# •
# 2.54k followers
# Microsoft
# company
# •
# 374 models
# •
# 12.4k followers
# Grammarly
# Enterprise
# company
# •
# 10 models
# •
# 160 followers
# Writer
# Enterprise
# company
# •
# 21 models
# •
# 267 followers
# Our Open Source
# We are building the foundation of ML tooling with the community.
# Transformers
# 144,426
# State-of-the-art ML for PyTorch, TensorFlow, JAX
# Diffusers
# 29,014
# State-of-the-art Diffusion models in PyTorch
# Safetensors
# 3,267
# Safe way to store/distribute neural network weights
# Hub Python Library
# 2,601
# Python client to interact with the Hugging Face Hub
# Tokenizers
# 9,683
# Fast tokenizers optimized for research & production
# TRL
# 13,778
# Train transformers LMs with reinforcement learning
# Transformers.js
# 13,607
# State-of-the-art ML running directly in your browser
# smolagents
# 18,748
# Smol library to build great agents in Python
# PEFT
# 18,428
# Parameter-efficient finetuning for large language models
# Datasets
# 20,126
# Access & share datasets for any ML tasks
# Text Generation Inference
# 10,124
# Serve language models with TGI optimized toolkit
# Accelerate
# 8,725
# Train PyTorch models with multi-GPU, TPU, mixed precision
# System theme
# Website
# Models
# Datasets
# Spaces
# Tasks
# Inference Endpoints
# HuggingChat
# Company
# About
# Brand assets
# Terms of service
# Privacy
# Jobs
# Press
# Resources
# Learn
# Documentation
# Blog
# Forum
# Service Status
# Social
# GitHub
# Twitter
# LinkedIn
# Discord
#
#
#
# home page
# Webpage Title:
# Hugging Face – The AI community building the future.
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Posts
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# The AI community building the future.
# The platform where the machine learning community collaborates on models, datasets, and applications.
# Explore AI Apps
# or
# Browse 1M+ models
# Trending on
# this week
# Models
# nvidia/parakeet-tdt-0.6b-v2
# Updated
# 1 day ago
# •
# 202k
# •
# 897
# nari-labs/Dia-1.6B
# Updated
# 4 days ago
# •
# 177k
# •
# 2.21k
# lodestones/Chroma
# Updated
# about 20 hours ago
# •
# 561
# Lightricks/LTX-Video
# Updated
# 2 days ago
# •
# 297k
# •
# 1.51k
# PrimeIntellect/INTELLECT-2
# Updated
# 5 days ago
# •
# 609
# •
# 152
# Browse 1M+ models
# Spaces
# Running
# 6.64k
# 6.64k
# DeepSite
# 🐳
# Generate any application with DeepSeek
# Running
# on
# CPU Upgrade
# 650
# 650
# Computer Agent
# 🖥
# Interact with an AI agent to perform web tasks
# Running
# on
# Zero
# 361
# 361
# DreamO
# 🐨
# A Unified Framework for Image Customization
# Running
# 403
# 403
# FLUX Pro Unlimited
# 🔥
# Use the FLUX-Pro model as much as you want.
# Running
# on
# Zero
# 179
# 179
# NSFW Uncensored image to video
# 🎬
# MAX ~60sec Video - AI Limits
# Browse 400k+ applications
# Datasets
# openbmb/Ultra-FineWeb
# Updated
# 9 days ago
# •
# 5.65k
# •
# 63
# PrimeIntellect/INTELLECT-2-RL-Dataset
# Updated
# 5 days ago
# •
# 447
# •
# 41
# nvidia/OpenCodeReasoning
# Updated
# 13 days ago
# •
# 13.6k
# •
# 412
# nvidia/OpenMathReasoning
# Updated
# 8 days ago
# •
# 37.8k
# •
# 232
# DMindAI/DMind_Benchmark
# Updated
# about 1 hour ago
# •
# 2.23k
# •
# 75
# Browse 250k+ datasets
# The Home of Machine Learning
# Create, discover and collaborate on ML better.
# The collaboration platform
# Host and collaborate on unlimited public models, datasets and applications.
# Move faster
# With the HF Open source stack.
# Explore all modalities
# Text, image, video, audio or even 3D.
# Build your portfolio
# Share your work with the world and build your ML profile.
# Sign Up
# Accelerate your ML
# We provide paid Compute and Enterprise solutions.
# Compute
# Deploy on optimized
# Inference Endpoints
# or update your
# Spaces applications
# to a GPU in a few clicks.
# View pricing
# Starting at $0.60/hour for GPU
# Enterprise
# Give your team the most advanced platform to build AI with enterprise-grade security, access controls and
# 			dedicated support.
# Getting started
# Starting at $20/user/month
# Single Sign-On
# Regions
# Priority Support
# Audit Logs
# Resource Groups
# Private Datasets Viewer
# More than 50,000 organizations are using Hugging Face
# Ai2
# Enterprise
# non-profit
# •
# 757 models
# •
# 3.28k followers
# AI at Meta
# Enterprise
# company
# •
# 2.12k models
# •
# 5.98k followers
# Amazon
# company
# •
# 20 models
# •
# 3.16k followers
# Google
# company
# •
# 991 models
# •
# 13.2k followers
# Intel
# company
# •
# 221 models
# •
# 2.54k followers
# Microsoft
# company
# •
# 374 models
# •
# 12.4k followers
# Grammarly
# Enterprise
# company
# •
# 10 models
# •
# 160 followers
# Writer
# Enterprise
# company
# •
# 21 models
# •
# 267 followers
# Our Open Source
# We are building the foundation of ML tooling with the community.
# Transformers
# 144,426
# State-of-the-art ML for PyTorch, TensorFlow, JAX
# Diffusers
# 29,014
# State-of-the-art Diffusion models in PyTorch
# Safetensors
# 3,267
# Safe way to store/distribute neural network weights
# Hub Python Library
# 2,601
# Python client to interact with the Hugging Face Hub
# Tokenizers
# 9,683
# Fast tokenizers optimized for research & production
# TRL
# 13,778
# Train transformers LMs with reinforcement learning
# Transformers.js
# 13,607
# State-of-the-art ML running directly in your browser
# smolagents
# 18,748
# Smol library to build great agents in Python
# PEFT
# 18,428
# Parameter-efficient finetuning for large language models
# Datasets
# 20,126
# Access & share datasets for any ML tasks
# Text Generation Inference
# 10,124
# Serve language models with TGI optimized toolkit
# Accelerate
# 8,725
# Train PyTorch models with multi-GPU, TPU, mixed precision
# System theme
# Website
# Models
# Datasets
# Spaces
# Tasks
# Inference Endpoints
# HuggingChat
# Company
# About
# Brand assets
# Terms of service
# Privacy
# Jobs
# Press
# Resources
# Learn
# Documentation
# Blog
# Forum
# Service Status
# Social
# GitHub
# Twitter
# LinkedIn
# Discord
#
#
#
# about page
# Webpage Title:
# huggingface (Hugging Face)
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Posts
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# Hugging Face
# Enterprise
# company
# Verified
# https://huggingface.co
# huggingface
# huggingface
# Activity Feed
# Follow
# 38,090
# AI & ML interests
# The AI community building the future.
# Recent Activity
# thomasglopes
# new
# activity
# 1 day ago
# huggingface/inference-playground:
# [FEEDBACK] Inference Playground
# mishig
# updated
# a Space
# 1 day ago
# huggingface/inference-playground
# pepijn223
# updated
# a dataset
# 1 day ago
# huggingface/documentation-images
# View all activity
# Articles
# Yay! Organizations can now publish blog Articles
# Jan 20
# •
# 43
# Team members
# 215
# +181
# +168
# +147
# +137
# +117
# Organization Card
# Community
# About org cards
# 👋 Hi!
# We are on a mission to democratize
# good
# machine learning, one commit at a time.
# If that sounds like something you should be doing, why don't you
# join us
# !
# For press enquiries, you can
# ✉️ contact our team here
# .
# Collections
# 1
# DistilBERT release
# Original DistilBERT model, checkpoints obtained from using teacher-student learning from the original BERT checkpoints.
# distilbert/distilbert-base-cased
# Fill-Mask
# •
# Updated
# May 6, 2024
# •
# 232k
# •
# •
# 46
# distilbert/distilbert-base-uncased
# Fill-Mask
# •
# Updated
# May 6, 2024
# •
# 11.8M
# •
# •
# 685
# distilbert/distilbert-base-multilingual-cased
# Fill-Mask
# •
# Updated
# May 6, 2024
# •
# 9.65M
# •
# 189
# distilbert/distilbert-base-uncased-finetuned-sst-2-english
# Text Classification
# •
# Updated
# Dec 19, 2023
# •
# 4.22M
# •
# •
# 760
# spaces
# 26
# Sort:
# 		Recently updated
# pinned
# Running
# 87
# Number Tokenization Blog
# 📈
# Explore how tokenization affects arithmetic in LLMs
# huggingface
# Dec 14, 2024
# Running
# 166
# Inference Playground
# 🔋
# Set webpage theme based on user preference or system settings
# huggingface
# 1 day ago
# Running
# 7
# Space Build
# 🐨
# Generate static files for spaces
# huggingface
# 2 days ago
# Running
# 402
# AI Deadlines
# ⚡
# Generate project deadlines
# huggingface
# 18 days ago
# Running
# 97
# InferenceSupport
# 💥
# Discussions about the Inference Providers feature on the Hub
# huggingface
# Apr 16
# Running
# 538
# Open Source Ai Year In Review 2024
# 😻
# What happened in open-source AI this year, and what’s next?
# huggingface
# Jan 8
# Expand
# 							26
# 								spaces
# models
# 16
# Sort:
# 		Recently updated
# huggingface/timesfm-tourism-monthly
# Updated
# Mar 31
# •
# 244
# •
# 2
# huggingface/CodeBERTa-language-id
# Text Classification
# •
# Updated
# Mar 29, 2024
# •
# 811
# •
# •
# 62
# huggingface/falcon-40b-gptq
# Text Generation
# •
# Updated
# Jun 14, 2023
# •
# 27
# •
# 12
# huggingface/autoformer-tourism-monthly
# Updated
# May 24, 2023
# •
# 15k
# •
# 9
# huggingface/distilbert-base-uncased-finetuned-mnli
# Text Classification
# •
# Updated
# Mar 22, 2023
# •
# 344
# •
# 2
# huggingface/informer-tourism-monthly
# Updated
# Feb 24, 2023
# •
# 15.3k
# •
# 6
# huggingface/time-series-transformer-tourism-monthly
# Updated
# Feb 23, 2023
# •
# 4.88k
# •
# 21
# huggingface/the-no-branch-repo
# Text-to-Image
# •
# Updated
# Feb 10, 2023
# •
# 18
# •
# 5
# huggingface/CodeBERTa-small-v1
# Fill-Mask
# •
# Updated
# Jun 27, 2022
# •
# 126k
# •
# •
# 81
# huggingface/test-model-repo
# Updated
# Nov 19, 2021
# •
# 1
# Expand
# 							16
# 								models
# datasets
# 42
# Sort:
# 		Recently updated
# huggingface/documentation-images
# Viewer
# •
# Updated
# 1 day ago
# •
# 52
# •
# 2.68M
# •
# 63
# huggingface/transformers-metadata
# Viewer
# •
# Updated
# 10 days ago
# •
# 1.67k
# •
# 1.08k
# •
# 23
# huggingface/badges
# Viewer
# •
# Updated
# Apr 8
# •
# 1
# •
# 1.59M
# •
# 43
# huggingface/policy-docs
# Updated
# Mar 20
# •
# 1.31k
# •
# 10
# huggingface/diffusers-metadata
# Viewer
# •
# Updated
# Mar 15
# •
# 69
# •
# 791
# •
# 7
# huggingface/gemini-results-2025-03-03
# Viewer
# •
# Updated
# Mar 4
# •
# 17
# •
# 29
# huggingface/gemini-results-2025-02-28
# Viewer
# •
# Updated
# Mar 1
# •
# 21
# •
# 34
# huggingface/gemini-results-2025-02-27
# Viewer
# •
# Updated
# Feb 28
# •
# 24
# •
# 31
# huggingface/gemini-results-2025-02-25
# Viewer
# •
# Updated
# Feb 26
# •
# 32
# •
# 77
# huggingface/gemini-results-2025-02-24
# Viewer
# •
# Updated
# Feb 25
# •
# 32
# •
# 36
# Expand
# 							42
# 								datasets
# System theme
# Company
# TOS
# Privacy
# About
# Jobs
# Website
# Models
# Datasets
# Spaces
# Pricing
# Docs
#
#
#
# careers page
# Webpage Title:
# Hugging Face - Current Openings
# Webpage Contents:
#
#
#
#
# blog page
# Webpage Title:
# Hugging Face – Blog
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Posts
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# Blog, Articles, and discussions
# New Article
# Everything
# community
# guide
# open source collab
# partnerships
# research
# NLP
# Audio
# CV
# RL
# ethics
# Diffusion
# Game Development
# RLHF
# Leaderboard
# Case Studies
# LeRobot
# The Transformers Library: standardizing model definitions
# By
# lysandre
# May 15, 2025
# •
# 76
# Community Articles
# view all
# Falcon-Edge: A series of powerful, universal, fine-tunable 1.58bit language models.
# By
# tiiuae
# and 9 others
# •
# 2 days ago
# •
# 31
# TinyAgents: A Minimal Experiment with Code Agents and MCP Tools
# By
# albertvillanova
# •
# 1 day ago
# •
# 20
# CycleNavigator: Visualizing Economic and Political Cycles Through AI
# By
# openfree
# •
# 4 days ago
# •
# 18
# 🦸🏻#14: What Is MCP, and Why Is Everyone – Suddenly!– Talking About It?
# By
# Kseniase
# •
# Mar 17
# •
# 252
# I trained a Language Model to schedule events with GRPO!
# By
# anakin87
# •
# 18 days ago
# •
# 70
# Highlights from the First ICLR 2025 Watermarking Workshop
# By
# hadyelsahar
# and 4 others
# •
# 3 days ago
# •
# 9
# Code a simple RAG from scratch
# By
# ngxson
# •
# Oct 29, 2024
# •
# 74
# Good answers are not necessarily factual answers: an analysis of hallucination in leading LLMs
# By
# davidberenstein1957
# and 1 other
# •
# 10 days ago
# •
# 23
# All LLMs Will Be Sparse BitNet Hybrids
# By
# codys12
# •
# 4 days ago
# •
# 7
# The Large Language Model Course
# By
# mlabonne
# •
# Jan 16
# •
# 177
# Page-to-Video: Generate videos from webpages 🪄🎬
# By
# burtenshaw
# •
# 11 days ago
# •
# 25
# Uncensor any LLM with abliteration
# By
# mlabonne
# •
# Jun 13, 2024
# •
# 555
# DeepSeek-R1 Dissection: Understanding PPO & GRPO Without Any Prior Reinforcement Learning Knowledge
# By
# NormalUhr
# •
# Feb 7
# •
# 136
# Introduction to State Space Models (SSM)
# By
# lbourdois
# •
# Jul 19, 2024
# •
# 134
# ColPali: Efficient Document Retrieval with Vision Language Models 👀
# By
# manu
# •
# Jul 5, 2024
# •
# 250
# Navigating the RLHF Landscape: From Policy Gradients to PPO, GAE, and DPO for LLM Alignment
# By
# NormalUhr
# •
# Feb 11
# •
# 34
# CircleGuardBench: New Standard for Evaluating AI Moderation Models
# By
# whitecircle-ai
# and 7 others
# •
# 10 days ago
# •
# 52
# Merge Large Language Models with mergekit
# By
# mlabonne
# •
# Jan 9, 2024
# •
# 118
# Bamba-9B-v2 - Fast and powerful!
# By
# ibm-ai-platform
# and 12 others
# •
# 19 days ago
# •
# 31
# A Deep Dive into Alibaba’s ZeroSearch: Why It Changes LLM-Centric Search Workflows
# By
# lynn-mikami
# •
# 5 days ago
# •
# 3
# Improving Hugging Face Model Access for Kaggle Users
# By
# roseberryv
# May 14, 2025
# •
# 18
# Blazingly fast whisper transcriptions with Inference Endpoints
# By
# mfuntowicz
# May 13, 2025
# •
# 56
# Vision Language Models (Better, Faster, Stronger)
# By
# merve
# May 12, 2025
# •
# 306
# LeRobot Community Datasets: The “ImageNet” of Robotics — When and How?
# By
# danaaubakirova
# May 11, 2025
# •
# 45
# How to Build an MCP Server with Gradio
# By
# abidlabs
# April 30, 2025
# •
# 103
# Welcoming Llama Guard 4 on Hugging Face Hub
# By
# merve
# April 29, 2025
# •
# 36
# The 4 Things Qwen-3's Chat Template Teaches Us
# By
# cfahlgren1
# April 30, 2025
# •
# 38
# Tiny Agents: a MCP-powered agent in 50 lines of code
# By
# julien-c
# April 25, 2025
# •
# 240
# Introducing AutoRound: Intel’s Advanced Quantization for LLMs and VLMs
# By
# wenhuach
# April 29, 2025
# •
# 26
# 17 Reasons Why Gradio Isn't Just Another UI Library
# By
# ysharma
# April 16, 2025
# •
# 32
# Cohere on Hugging Face Inference Providers 🔥
# By
# burtenshaw
# April 16, 2025
# •
# 125
# Introducing HELMET
# By
# hyen
# April 16, 2025
# •
# 27
# Hugging Face to sell open-source robots thanks to Pollen Robotics acquisition 🤖
# By
# thomwolf
# April 14, 2025
# •
# 46
# 4M Models Scanned: Protect AI + Hugging Face 6 Months In
# By
# sean-pai
# April 14, 2025
# •
# 29
# Previous
# 1
# 2
# 3
# ...
# 41
# Next
# Community Articles
# Sort:
# 		Trending
# Falcon-Edge: A series of powerful, universal, fine-tunable 1.58bit language models.
# By
# tiiuae
# and 9 others
# •
# 2 days ago
# •
# 31
# TinyAgents: A Minimal Experiment with Code Agents and MCP Tools
# By
# albertvillanova
# •
# 1 day ago
# •
# 20
# CycleNavigator: Visualizing Economic and Political Cycles Through AI
# By
# openfree
# •
# 4 days ago
# •
# 18
# 🦸🏻#14: What Is MCP, and Why Is Everyone – Suddenly!– Talking About It?
# By
# Kseniase
# •
# Mar 17
# •
# 252
# I trained a Language Model to schedule events with GRPO!
# By
# anakin87
# •
# 18 days ago
# •
# 70
# Highlights from the First ICLR 2025 Watermarking Workshop
# By
# hadyelsahar
# and 4 others
# •
# 3 days ago
# •
# 9
# Code a simple RAG from scratch
# By
# ngxson
# •
# Oct 29, 2024
# •
# 74
# Good answers are not necessarily factual answers: an analysis of hallucination in leading LLMs
# By
# davidberenstein1957
# and 1 other
# •
# 10 days ago
# •
# 23
# All LLMs Will Be Sparse BitNet Hybrids
# By
# codys12
# •
# 4 days ago
# •
# 7
# The Large Language Model Course
# By
# mlabonne
# •
# Jan 16
# •
# 177
# Page-to-Video: Generate videos from webpages 🪄🎬
# By
# burtenshaw
# •
# 11 days ago
# •
# 25
# Uncensor any LLM with abliteration
# By
# mlabonne
# •
# Jun 13, 2024
# •
# 555
# DeepSeek-R1 Dissection: Understanding PPO & GRPO Without Any Prior Reinforcement Learning Knowledge
# By
# NormalUhr
# •
# Feb 7
# •
# 136
# Introduction to State Space Models (SSM)
# By
# lbourdois
# •
# Jul 19, 2024
# •
# 134
# ColPali: Efficient Document Retrieval with Vision Language Models 👀
# By
# manu
# •
# Jul 5, 2024
# •
# 250
# Navigating the RLHF Landscape: From Policy Gradients to PPO, GAE, and DPO for LLM Alignment
# By
# NormalUhr
# •
# Feb 11
# •
# 34
# CircleGuardBench: New Standard for Evaluating AI Moderation Models
# By
# whitecircle-ai
# and 7 others
# •
# 10 days ago
# •
# 52
# Merge Large Language Models with mergekit
# By
# mlabonne
# •
# Jan 9, 2024
# •
# 118
# Bamba-9B-v2 - Fast and powerful!
# By
# ibm-ai-platform
# and 12 others
# •
# 19 days ago
# •
# 31
# A Deep Dive into Alibaba’s ZeroSearch: Why It Changes LLM-Centric Search Workflows
# By
# lynn-mikami
# •
# 5 days ago
# •
# 3
# View all
# System theme
# Company
# TOS
# Privacy
# About
# Jobs
# Website
# Models
# Datasets
# Spaces
# Pricing
# Docs
#
#
#
# company page
# Webpage Title:
# Hugging Face | LinkedIn
# Webpage Contents:
# Skip to main content
# LinkedIn
# Articles
# People
# Learning
# Jobs
# Games
# Get the app
# Join now
# Sign in
# Hugging Face
# Software Development
# The AI community building the future.
# See jobs
# Follow
# View all 539 employees
# Report this company
# About us
# The AI community building the future.
# Website
# https://huggingface.co
# External link for Hugging Face
# Industry
# Software Development
# Company size
# 51-200 employees
# Type
# Privately Held
# Founded
# 2016
# Specialties
# machine learning, natural language processing, and deep learning
# Products
# Hugging Face
# Hugging Face
# Natural Language Processing (NLP) Software
# We‚Äôre on a journey to solve and democratize artificial intelligence through natural language.
# Locations
# Primary
# Get directions
# Paris, FR
# Get directions
# Employees at Hugging Face
# Ludovic Huraux
# Rajat Arya
# Tech Lead & Software Engineer @ HF | prev: co-founder XetHub, Apple, Turi, AWS, Microsoft
# Jeff Boudier
# Product + Growth at Hugging Face
# Terrence Rohan
# Seed Investor
# See all employees
# Updates
# Hugging Face
# reposted this
# Clem Delangue ü§ó
# Clem Delangue ü§ó is an Influencer
# Co-founder & CEO at Hugging Face
# 23h
# Report this post
# 3,000+ students for the
# Hugging Face
# MCP class already!
# 265
# 19 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Merve Noyan
# open-sourceress at ü§ó | Google Developer Expert in Machine Learning, MSc Candidate in Data Science
# 1d
# Report this post
# New sota open-source depth estimation: Marigold IID üåº
#
# > normal maps, depth maps of scenes & faces
# > get albedo (true color) and BRDF (texture) maps of scenes, they even release a depth-to-3D printer format demo üòÆ
# links to all models and demos in comments ü§ó
# ‚Ä¶more
# 240
# 5 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Ben Burtenshaw
# Machine Learning Advocacy @ ü§ó Hugging Face
# 1d
# Edited
# Report this post
# The MCP course is free, open source, and with Apache 2 license.
#
# ‚≠êÔ∏è
# https://lnkd.in/eTuSr-Uh
# So if you‚Äôre working on MCP you can do any of this:
#
# - take the course and reuse it for your own educational/ dev advocacy projects
# - collaborate with us on new units about your projects or interests
# - star the repo on github so more devs hear about it and join in
#
# Note, some of these options are cooler than others.
# 942
# 15 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Vaibhav Srivastav
# GPU poor @ Hugging Face
# 2d
# Report this post
# LETS GOO: Hugging Face just dropped the MCP Course everything you need to know about Model Context Protocol AND how to use it!! üí•
#
# Sign up today - totally free and open source course!
#
# From understanding what MCP is to connecting LLMs, to deploying your own MCP servers - we've got you covered! ü§ó
#
# Link to the course in comments!
# 787
# 26 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Gradio
# 63,623 followers
# 2d
# Report this post
# Learn about the trio powering Model Context Protocol (MCP)üëá
#
# üß† Host = the LLM app (Claude Desktop, IDEs, even your Gradio Chatbots)
# üß∞ Server = the tool with specific capability (APIs or Gradio apps)
# üîó Client = maintains 1:1 connection with the Server from inside the Host
#
# Guides for further reading and building MCP-powered apps üëá
# üöÄ Create end-to-end applications with Gradio chat interface as the Host and Gradio apps as Servers:
# https://lnkd.in/gTpTJMCy
# üî• Create MCP Servers with Gradio for your IDEs, Claude Desktop, or custom Hosts:
# https://lnkd.in/g2yg-NGX
# 49
# 3 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Lysandre Debut
# COSO - Chief Open Source Officer at Hugging Face
# 2d
# Report this post
# The Transformers library is undergoing it's largest pivot to date üôå
#
# It now cements its role as the central model definition, irrespective of the backend and runner. One ground truth to bring more reliability across the ecosystem.
#
# This comes into play as Transformers becomes a backend of:
#
# - most popular inference engines like vLLM, SGLang, TGI, TensorRT, ...
# - training frameworks like Axolotl, Unsloth, DeepSpeed, FSDP, PyTorch-Lightning, ...
# - and adjacent modeling libraries like
# llama.cpp
# , MLX, ONNX, ...
#
# Transformers is the pivot across frameworks: if a model is integrated, then you're certain it is handled by the rest of the ecosystem.
#
# In a field where ML releases are more and more frequent, keeping track of integrations in all downstream libraries can become a headache.
#
# By having Transformers as a backend, you get immediate access to all 300+ supported architectures, and you're ensured immediate access to upcoming model releases.
#
# This often means day-0 access, but also community-fixes, and a shared baseline for evaluation.
#
# This means that we'll strive to continuously improve Transformers so that:
#
# -  Integrations are simpler & faster
# - Models continue being adaptable, customizable
# - Model definitions remain simple, easily augmented by downstream libraries.
#
# Read more about it in the following blog post:
# https://lnkd.in/eQjmcWxF
# 1,107
# 17 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Ben Burtenshaw
# Machine Learning Advocacy @ ü§ó Hugging Face
# 2d
# Report this post
# We're thrilled to announce the launch of our comprehensive Model Context Protocol (MCP) Course! This free program is designed to take learners from foundational understanding to practical application of MCP in AI.
#
# Join the course on the hub:
# https://lnkd.in/eTuSr-Uh
# In this course, you will:
# üìñ Study Model Context Protocol in theory, design, and practice.
# üßëüíª Learn to use established MCP SDKs and frameworks.
# üíæ Share your projects and explore applications created by the community.
# üèÜ Participate in challenges and evaluate your MCP implementations.
# üéì Earn a certificate of completion.
#
# At the end, you'll understand how MCP works and how to build your own AI applications that leverage external data and tools using the latest MCP standards.
# 2,297
# 59 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Marc Sun
# ML Engineer @HuggingFace ü§ó | CentraleSup√©lec | Columbia
# 2d
# Report this post
# üöÄ Accelerate v1.7.0 is here!
#
# Highlights of this release:
# - üß© Regional compilation by
# Ilyas Moutawwakil
# - üß† Layerwise casting hook by
# Sayak Paul
# , a widely used feature in diffusers repository
# - ‚ö°QLoRA support for FSDPv2 by
# Wing Lian
# Release notes:
# https://lnkd.in/eTxrarYa
# 93
# 5 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Pollen Robotics
# 10,537 followers
# 2d
# Report this post
# 3 robots heading to
# Humanoids Summit
# London 2025!
#
# If you're around, come say hi. We'll be showing:
#  ü§ñ Reachy 2, now able to react emotionally and understand multiple languages. We'll also show you what Reachy is able to do through teleoperation.
#  ü¶Ü Mini Duck,
# Antoine Pirrone
# 's project, doing what it does best: wandering freely and charming everyone.
#  ü¶æ And for the first time ever in public: David A6DoF, a joint project by Antoine and
# Augustin CRAMPETTE
# We‚Äôre also proud to see
# Santiago Ismael Pavon
# and
# Remi Cadene
# from
# Hugging Face
# speaking on stage, diving into some of the key topics around Embodied AI.
#
#  üìçSee you there?
# 62
# 4 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Shaun Smith
# llmindset.co.uk
# 3d
# Report this post
# A couple of weeks ago
# Julien Chaumond
# shared Tiny Agent - 50 lines of code that showed how powerful combining LLMs and Tools together is (with MCP providing the "glue").
#
# We've made a small, but very useful update:- you can now connect to Remote MCP Servers (including
# Gradio
# endpoints) straight from the command line - making it even easier to add Agent Capabilities to that while loop. Enjoy!
# 119
# 3 Comments
# Like
# Comment
# Share
# Join now to see what you are missing
# Find people you know at Hugging Face
# Browse recommended jobs for you
# View all updates, news, and articles
# Join now
# Similar pages
# Anthropic
# Research Services
# Perplexity
# Software Development
# San Francisco, California
# Mistral AI
# Technology, Information and Internet
# Paris, France
# OpenAI
# Research Services
# San Francisco, CA
# LangChain
# Technology, Information and Internet
# Generative AI
# Technology, Information and Internet
# DeepLearning.AI
# Software Development
# Palo Alto, California
# Google DeepMind
# Research Services
# London, London
# Cohere
# Software Development
# Toronto, Ontario
# LlamaIndex
# Technology, Information and Internet
# San Francisco, California
# Show more similar pages
# Show fewer similar pages
# Browse jobs
# Engineer jobs
# 555,845 open jobs
# Machine Learning Engineer jobs
# 148,937 open jobs
# Scientist jobs
# 48,969 open jobs
# Software Engineer jobs
# 300,699 open jobs
# Analyst jobs
# 694,057 open jobs
# Intern jobs
# 71,196 open jobs
# Developer jobs
# 258,935 open jobs
# Manager jobs
# 1,880,925 open jobs
# Product Manager jobs
# 199,941 open jobs
# Director jobs
# 1,220,357 open jobs
# Python Developer jobs
# 46,642 open jobs
# Data Scientist jobs
# 264,158 open jobs
# Data Analyst jobs
# 329,009 open jobs
# Senior Software Engineer jobs
# 78,145 open jobs
# Project Manager jobs
# 253,048 open jobs
# Researcher jobs
# 195,654 open jobs
# Associate jobs
# 1,091,945 open jobs
# Data Engineer jobs
# 192,126 open jobs
# Vice President jobs
# 235,270 open jobs
# Specialist jobs
# 768,666 open jobs
# Show more jobs like this
# Show fewer jobs like this
# Funding
# Hugging Face
# 8 total rounds
# Last Round
# Series unknown
# Sep 1, 2024
# External Crunchbase Link for last round of funding
# See more info on
# crunchbase
# More searches
# More searches
# Engineer jobs
# Scientist jobs
# Machine Learning Engineer jobs
# Software Engineer jobs
# Intern jobs
# Developer jobs
# Analyst jobs
# Manager jobs
# Senior Software Engineer jobs
# Data Scientist jobs
# Researcher jobs
# Product Manager jobs
# Director jobs
# Associate jobs
# Intelligence Specialist jobs
# Data Analyst jobs
# Data Science Specialist jobs
# Python Developer jobs
# Quantitative Analyst jobs
# Project Manager jobs
# Account Executive jobs
# Specialist jobs
# Data Engineer jobs
# Designer jobs
# Quantitative Researcher jobs
# Consultant jobs
# Solutions Architect jobs
# Vice President jobs
# User Experience Designer jobs
# Head jobs
# Full Stack Engineer jobs
# Engineering Manager jobs
# Software Engineer Intern jobs
# Junior Software Engineer jobs
# Software Intern jobs
# Product Designer jobs
# Solutions Engineer jobs
# Staff Software Engineer jobs
# Program Manager jobs
# Senior Scientist jobs
# Writer jobs
# Research Intern jobs
# Senior Product Manager jobs
# Summer Intern jobs
# Account Manager jobs
# Recruiter jobs
# Lead jobs
# Research Engineer jobs
# Computer Science Intern jobs
# Platform Engineer jobs
# Junior Developer jobs
# Android Developer jobs
# User Experience Researcher jobs
# Java Software Engineer jobs
# Site Reliability Engineer jobs
# Graduate jobs
# Software Engineering Manager jobs
# Representative jobs
# Business Development Specialist jobs
# Computer Engineer jobs
# LinkedIn
# © 2025
# About
# Accessibility
# User Agreement
# Privacy Policy
# Cookie Policy
# Copyright Policy
# Brand Policy
# Guest Controls
# Community Guidelines
# ÿßŸÑÿπÿ±ÿ®Ÿäÿ© (Arabic)
# ‡¶¨‡¶æ‡¶Ç‡¶≤‡¶æ (Bangla)
# ƒåe≈°tina (Czech)
# Dansk (Danish)
# Deutsch (German)
# ŒïŒªŒªŒ∑ŒΩŒπŒ∫Œ¨ (Greek)
# English (English)
# Espa√±ol (Spanish)
# ŸÅÿßÿ±ÿ≥€å (Persian)
# Suomi (Finnish)
# Fran√ßais (French)
# ‡§π‡§ø‡§Ç‡§¶‡•Ä (Hindi)
# Magyar (Hungarian)
# Bahasa Indonesia (Indonesian)
# Italiano (Italian)
# ◊¢◊ë◊®◊ô◊™ (Hebrew)
# Êó•Êú¨Ë™û (Japanese)
# ÌïúÍµ≠Ïñ¥ (Korean)
# ‡§Æ‡§∞‡§æ‡§†‡•Ä (Marathi)
# Bahasa Malaysia (Malay)
# Nederlands (Dutch)
# Norsk (Norwegian)
# ‡®™‡©∞‡®ú‡®æ‡®¨‡©Ä (Punjabi)
# Polski (Polish)
# Portugu√™s (Portuguese)
# Rom√¢nƒÉ (Romanian)
# –†—É—Å—Å–∫–∏–π (Russian)
# Svenska (Swedish)
# ‡∞§‡±Ü‡∞≤‡±Å‡∞ó‡±Å (Telugu)
# ‡∏†‡∏≤‡∏©‡∏≤‡πÑ‡∏ó‡∏¢ (Thai)
# Tagalog (Tagalog)
# T√ºrk√ße (Turkish)
# –£–∫—Ä–∞—ó–Ω—Å—å–∫–∞ (Ukrainian)
# Ti·∫øng Vi·ªát (Vietnamese)
# ÁÆÄ‰Ωì‰∏≠Êñá (Chinese (Simplified))
# Ê≠£È´î‰∏≠Êñá (Chinese (Traditional))
# Language
# Agree & Join LinkedIn
# By clicking Continue to join or sign in, you agree to LinkedIn‚Äôs
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# Sign in to see who you already know at Hugging Face
# Sign in
# Welcome back
# Email or phone
# Password
# Show
# Forgot password?
# Sign in
# or
# By clicking Continue to join or sign in, you agree to LinkedIn‚Äôs
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# New to LinkedIn?
# Join now
# or
# New to LinkedIn?
# Join now
# By clicking Continue to join or sign in, you agree to LinkedIn‚Äôs
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# LinkedIn
# LinkedIn is better on the app
# Don‚Äôt have the app? Get it in the Microsoft Store.
# Open the app
#
#
#
# community forum
# Webpage Title:
# Hugging Face Forums - Hugging Face Community Discussion
# Webpage Contents:
# Hugging Face Forums
# Topic
# Replies
# Views
# Activity
# RoFormer (Eng language)
# Models
# 4
# 13
# May 17, 2025
# Request for Dofollow Links on Published Blog Post (Pro User)
# Beginners
# 1
# 6
# May 17, 2025
# Huggingface trl GRPO loss is always zero
# Beginners
# 2
# 10
# May 17, 2025
# Has inference API stopped returning text embeddings?
# Inference Endpoints on the Hub
# 1
# 17
# May 17, 2025
# Higher importance to new tokens
# Beginners
# 1
# 13
# May 16, 2025
# Help this newbie
# Beginners
# 6
# 64
# May 15, 2025
# Question about llama fine tuning dataset token string
# Beginners
# 1
# 8
# May 17, 2025
# Code execution failed at line -- CodeAgents
# Beginners
# 3
# 22
# May 16, 2025
# “Use this model”->Ollama: can't pull model with Q4
# 🤗Hub
# 4
# 42
# May 15, 2025
# Did something change recently regarding caching / ETags?
# 🤗Hub
# 1
# 7
# May 17, 2025
# PRO subscription
# Beginners
# 1
# 26
# May 16, 2025
# Persistent 404 Not Found Errors with Public Inference API
# Inference Endpoints on the Hub
# 8
# 222
# May 15, 2025
# Cannot verify in Discord
# Beginners
# 1
# 10
# May 16, 2025
# Pre training  on a corpus of raw human thoughts : feasability and risks
# Research
# 4
# 18
# May 16, 2025
# GradioUI + Smolagents + MCP "Event loop is closed"
# Intermediate
# 1
# 11
# May 16, 2025
# AI Memory : The Simplest System That Beats Every Complex Solution
# Research
# 4
# 33
# May 17, 2025
# AttributeError: 'CustomQwen3Model' object has no attribute 'config'
# 🤗Transformers
# 1
# 7
# May 16, 2025
# Cuda out of memory in SD3
# 🤗Transformers
# 4
# 14
# May 16, 2025
# Stopiteration error
# 🤗Transformers
# 1
# 14
# May 16, 2025
# Solving Interrupted Downloads of Large Models on Hugging Face: Consistency Check Failure with deepseek-v3
# Beginners
# 1
# 8
# May 16, 2025
# Seeking arXiv Endorsement for cs.AI Submission — Motivation Structure in Human-like AI
# Beginners
# 0
# 8
# May 16, 2025
# FineTuning 7B model on 3080 laptop (16GO VRAM) issues
# Beginners
# 1
# 11
# May 16, 2025
# Requests returning a 404 error constantly
# Beginners
# 2
# 31
# May 16, 2025
# gPRC on Spaces 🥹
# Spaces
# 7
# 37
# May 16, 2025
# Inference API Rate Limits
# Inference Endpoints on the Hub
# 1
# 21
# May 16, 2025
# Persistent DNS Resolution Errors
# Spaces
# 19
# 360
# May 10, 2025
# Can I create a dataset for fine-tuning the llama model like in the main text?
# Beginners
# 2
# 15
# May 15, 2025
# Getting Not Found for model google/flan-t5-small (and others)
# Beginners
# 8
# 89
# May 16, 2025
# 🚀 New tool for AI manga creators: **MangaBuilder** (buildmanga.com)
# Intermediate
# 2
# 15
# May 16, 2025
# ZeroGPU space : No CUDA GPUs are available
# Spaces
# 3
# 66
# May 14, 2025
# next page →
# Home
# Categories
# Guidelines
# Terms of Service
# Privacy Policy
# Powered by
# Discourse
# , best viewed with JavaScript enabled
#
#
#
# status page
# Webpage Title:
#
# Hugging Face status
#
# Webpage Contents:
# Status
# Maintenance
# Previous incidents
# Get updates
# Get status updates
# Get e-mail notifications whenever Hugging Face creates, updates or resolves an incident.
# Subscribe to specific components
# Current status by service
# Huggingface Hub
# Git Hosting and Serving
# HF Inference
# HF Endpoints
# Inference Endpoints UI
# Inference Endpoints API
# Spaces
# Spaces Proxy
# Subscribe
# All services are online
# Last updated on May 17 at 01:46pm EDT
# Current status by service
# Operational
# Huggingface Hub
# 30 days ago
# 60 days ago
# 90 days ago
# Today
# Git Hosting and Serving
# 30 days ago
# 60 days ago
# 90 days ago
# Today
# HF Inference
# 30 days ago
# 60 days ago
# 90 days ago
# Today
# HF Endpoints
# Operational
# Inference Endpoints UI
# 30 days ago
# 60 days ago
# 90 days ago
# Today
# Inference Endpoints API
# 30 days ago
# 60 days ago
# 90 days ago
# Today
# Spaces
# Operational
# Spaces Proxy
# 30 days ago
# 60 days ago
# 90 days ago
# Today
# Powered by
# Better Stack

# %%
system_prompt = "You are an assistant that analyzes the contents of several relevant pages from a company website \
and creates a short brochure about the company for prospective customers, investors and recruits. Respond in markdown.\
Include details of company culture, customers and careers/jobs if you have the information."

# Or uncomment the lines below for a more humorous brochure - this demonstrates how easy it is to incorporate 'tone':

# system_prompt = "You are an assistant that analyzes the contents of several relevant pages from a company website \
# and creates a short humorous, entertaining, jokey brochure about the company for prospective customers, investors and recruits. Respond in markdown.\
# Include details of company culture, customers and careers/jobs if you have the information."

# %%
def get_brochure_user_prompt(company_name, url):
    user_prompt = f"You are looking at a company called: {company_name}\n"
    user_prompt += f"Here are the contents of its landing page and other relevant pages; use this information to build a short brochure of the company in markdown.\n"
    user_prompt += get_all_details(url)
    user_prompt = user_prompt[:5_000] # Truncate if more than 5,000 characters
    return user_prompt

# %%
get_brochure_user_prompt("HuggingFace", "https://huggingface.co")
# Out:
# Found links: {'links': [{'type': 'about page', 'url': 'https://huggingface.co/huggingface'}, {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'}, {'type': 'blog page', 'url': 'https://huggingface.co/blog'}, {'type': 'company page', 'url': 'https://www.linkedin.com/company/huggingface/'}, {'type': 'community page', 'url': 'https://discuss.huggingface.co'}, {'type': 'enterprise page', 'url': 'https://huggingface.co/enterprise'}, {'type': 'pricing page', 'url': 'https://huggingface.co/pricing'}]}
# 'You are looking at a company called: HuggingFace\nHere are the contents of its landing page and other relevant pages; use this information to build a short brochure of the company in markdown.\nLanding page:\nWebpage Title:\nHugging Face – The AI community building the future.\nWebpage Contents:\nHugging Face\nModels\nDatasets\nSpaces\nPosts\nDocs\nEnterprise\nPricing\nLog In\nSign Up\nThe AI community building the future.\nThe platform where the machine learning community collaborates on models, datasets, and applications.\nExplore AI Apps\nor\nBrowse 1M+ models\nTrending on\nthis week\nModels\nnvidia/parakeet-tdt-0.6b-v2\nUpdated\n1 day ago\n•\n202k\n•\n897\nnari-labs/Dia-1.6B\nUpdated\n4 days ago\n•\n177k\n•\n2.21k\nlodestones/Chroma\nUpdated\nabout 20 hours ago\n•\n561\nLightricks/LTX-Video\nUpdated\n2 days ago\n•\n297k\n•\n1.51k\nPrimeIntellect/INTELLECT-2\nUpdated\n5 days ago\n•\n609\n•\n152\nBrowse 1M+ models\nSpaces\nRunning\n6.64k\n6.64k\nDeepSite\n🐳\nGenerate any application with DeepSeek\nRunning\non\nCPU Upgrade\n650\n650\nComputer Agent\n🖥\nInteract with an AI agent to perform web tasks\nRunning\non\nZero\n361\n361\nDreamO\n🐨\nA Unified Framework for Image Customization\nRunning\n403\n403\nFLUX Pro Unlimited\n🔥\nUse the FLUX-Pro model as much as you want.\nRunning\non\nZero\n179\n179\nNSFW Uncensored image to video\n🎬\nMAX ~60sec Video - AI Limits\nBrowse 400k+ applications\nDatasets\nopenbmb/Ultra-FineWeb\nUpdated\n9 days ago\n•\n5.65k\n•\n63\nPrimeIntellect/INTELLECT-2-RL-Dataset\nUpdated\n5 days ago\n•\n447\n•\n41\nnvidia/OpenCodeReasoning\nUpdated\n13 days ago\n•\n13.6k\n•\n412\nnvidia/OpenMathReasoning\nUpdated\n8 days ago\n•\n37.8k\n•\n232\nDMindAI/DMind_Benchmark\nUpdated\nabout 1 hour ago\n•\n2.23k\n•\n75\nBrowse 250k+ datasets\nThe Home of Machine Learning\nCreate, discover and collaborate on ML better.\nThe collaboration platform\nHost and collaborate on unlimited public models, datasets and applications.\nMove faster\nWith the HF Open source stack.\nExplore all modalities\nText, image, video, audio or even 3D.\nBuild your portfolio\nShare your work with the world and build your ML profile.\nSign Up\nAccelerate your ML\nWe provide paid Compute and Enterprise solutions.\nCompute\nDeploy on optimized\nInference Endpoints\nor update your\nSpaces applications\nto a GPU in a few clicks.\nView pricing\nStarting at $0.60/hour for GPU\nEnterprise\nGive your team the most advanced platform to build AI with enterprise-grade security, access controls and\n\t\t\tdedicated support.\nGetting started\nStarting at $20/user/month\nSingle Sign-On\nRegions\nPriority Support\nAudit Logs\nResource Groups\nPrivate Datasets Viewer\nMore than 50,000 organizations are using Hugging Face\nAi2\nEnterprise\nnon-profit\n•\n757 models\n•\n3.28k followers\nAI at Meta\nEnterprise\ncompany\n•\n2.12k models\n•\n5.98k followers\nAmazon\ncompany\n•\n20 models\n•\n3.16k followers\nGoogle\ncompany\n•\n991 models\n•\n13.2k followers\nIntel\ncompany\n•\n221 models\n•\n2.54k followers\nMicrosoft\ncompany\n•\n374 models\n•\n12.4k followers\nGrammarly\nEnterprise\ncompany\n•\n10 models\n•\n160 followers\nWriter\nEnterprise\ncompany\n•\n21 models\n•\n267 followers\nOur Open Source\nWe are building the foundation of ML tooling with the community.\nTransformers\n144,426\nState-of-the-art ML for PyTorch, TensorFlow, JAX\nDiffusers\n29,014\nState-of-the-art Diffusion models in PyTorch\nSafetensors\n3,267\nSafe way to store/distribute neural network weights\nHub Python Library\n2,601\nPython client to interact with the Hugging Face Hub\nTokenizers\n9,683\nFast tokenizers optimized for research & production\nTRL\n13,778\nTrain transformers LMs with reinforcement learning\nTransformers.js\n13,607\nState-of-the-art ML running directly in your browser\nsmolagents\n18,748\nSmol library to build great agents in Python\nPEFT\n18,428\nParameter-efficient finetuning for large language models\nDatasets\n20,126\nAccess & share datasets for any ML tasks\nText Gen ...

# %%
def create_brochure(company_name, url):
    response = openai.chat.completions.create(
        model=MODEL,
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": get_brochure_user_prompt(company_name, url)}
          ],
    )
    result = response.choices[0].message.content
    display(Markdown(result))

# %%
create_brochure("Anthropic", "https://anthropic.com")
# Out:
# Found links: {'links': [{'type': 'company page', 'url': 'https://www.anthropic.com/company'}, {'type': 'careers page', 'url': 'https://www.anthropic.com/careers'}, {'type': 'team page', 'url': 'https://www.anthropic.com/team'}, {'type': 'about page', 'url': 'https://www.anthropic.com/about'}, {'type': 'news page', 'url': 'https://www.anthropic.com/news'}]}
# ```markdown
# # Anthropic Company Brochure
#
# ## Overview
# At **Anthropic**, we are at the forefront of AI innovation, dedicated to creating safe and effective AI systems that prioritize humanity's long-term well-being. Our flagship product, **Claude**, is an intelligent AI model designed to assist in diverse applications from coding to customer support.
#
# ## Product Offerings
# ### Claude
# - **Claude 3.7 Sonnet**: Our most advanced AI model, offering enhanced capabilities.
# - **API Solutions**: Build AI-powered applications and customize user experiences using Claude.
# - **Educational Resources**: Through **Anthropic Academy**, we provide learning tools to help developers and users effectively utilize our AI technologies.
#
# ## Customers and Use Cases
# We cater to a wide range of clients including educational institutions, businesses for customer support, and developers seeking to integrate AI capabilities into their applications. Our case studies demonstrate successful partnerships that leverage Claude’s capabilities to accelerate growth and improve efficiencies.
#
# ## Core Values
# At Anthropic, we emphasize:
# - **Safety First**: We prioritize safe AI development, ensuring that our technologies promote human benefit.
# - **Transparency**: We are committed to open dialogues about AI impacts, including our Responsible Scaling Policy and ongoing research into AI safety.
# - **Empowerment**: Our tools and resources are designed not only to improve productivity but also to foster a responsible relationship between humans and machines.
#
# ## Company Culture
# Anthropic believes in an inclusive and innovative work environment that encourages diversity of thought. Our team comprises talented individuals passionate about AI and its societal impacts. We foster continuous learning and collaboration, providing opportunities for professional growth through initiatives like the **Anthropic Academy**.
#
# ### Careers
# We are actively seeking new talent to help craft the future of safe and reliable AI. Join our team and contribute to transformative projects that set industry standards for responsible AI use. Explore our **open roles** to find your place in our mission of building AI for good.
#
# ## Join Us
# Whether you are looking to use AI solutions, invest in groundbreaking technology, or explore a fulfilling career path in AI, **Anthropic** welcomes you to join our journey towards responsible and innovative AI development.
#
# ### Contact Information
# For inquiries or more information:
# - Visit our website: [Anthropic](https://www.anthropic.com)
# - Chat with Claude to learn more about our products and services.
# ```

# %% [markdown]
# ## Finally - a minor improvement
#
# With a small adjustment, we can change this so that the results stream back from OpenAI,
# with the familiar typewriter animation

# %%
def stream_brochure(company_name, url):
    stream = openai.chat.completions.create(
        model=MODEL,
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": get_brochure_user_prompt(company_name, url)}
          ],
        stream=True
    )
    
    response = ""
    display_handle = display(Markdown(""), display_id=True)
    for chunk in stream:
        response += chunk.choices[0].delta.content or ''
        response = response.replace("```","").replace("markdown", "")
        update_display(Markdown(response), display_id=display_handle.display_id)

# %%
stream_brochure("Anthropic", "https://anthropic.com")
# Out:
# Found links: {'links': [{'type': 'homepage', 'url': 'https://www.anthropic.com/'}, {'type': 'about page', 'url': 'https://www.anthropic.com/company'}, {'type': 'careers page', 'url': 'https://www.anthropic.com/careers'}, {'type': 'team page', 'url': 'https://www.anthropic.com/team'}, {'type': 'research page', 'url': 'https://www.anthropic.com/research'}, {'type': 'learning page', 'url': 'https://www.anthropic.com/learn'}, {'type': 'solutions page', 'url': 'https://www.anthropic.com/solutions/agents'}, {'type': 'customers page', 'url': 'https://www.anthropic.com/customers'}, {'type': 'transparency page', 'url': 'https://www.anthropic.com/transparency'}, {'type': 'news page', 'url': 'https://www.anthropic.com/news'}]}
# # Anthropic Company Brochure
#
# ## Welcome to Anthropic
#
# At Anthropic, we're dedicated to developing advanced AI technologies that prioritize safety and humanity's long-term well-being. Our flagship product, **Claude**, represents the forefront of AI innovative solutions, designed to empower users and businesses in groundbreaking ways.
#
# ---
#
# ## Our Vision
#
# We believe that knowledge is power, and as we navigate a future where machines possess immense knowledge, our mission is to ensure this technological advancement benefits humanity. Our commitment is reflected in our responsible approach to AI development, emphasizing safety, interpretability, and a thorough understanding of societal impacts.
#
# ### Key Values:
# - **Safety First:** Putting human impact at the forefront.
# - **Transparency:** Open communication of our methodologies and outcomes.
# - **Responsibility:** Thoughtful consideration of technology's broader effects.
#
# ---
#
# ## Meet Claude
#
# Introducing **Claude 3.7 Sonnet**, our most intelligent AI model yet! Claude enables users to create AI-powered applications that deliver custom experiences. Whether it be through coding solutions, customer support, or collaborative AI agents, Claude is designed to adapt and meet your needs.
#
# ### Product Features:
# - **Cross-Platform API:** Build versatile applications and custom solutions.
# - **Educational Resources:** Participate in the **Anthropic Academy** to learn the best practices in AI development.
# - **Research Backed:** Our models are continuously informed by cutting-edge research and real-world case studies.
#
# ---
#
# ## Our Customers
#
# Our diverse customer base includes enterprises across multiple industries, educators, and independent developers, all looking to harness AI for innovative solutions. Our solutions are tailored to suit the digitized environments of various sectors, ensuring scalability and effectiveness.
#
# ---
#
# ## Join Our Team
#
# We're looking for passionate individuals who are eager to contribute to the future of safe AI development. At Anthropic, you will find:
#
# - **Innovative Environment:** Engage in pioneering research that shapes the landscape of AI.
# - **Collaborative Culture:** Our team thrives on teamwork, transparency, and creativity in problem-solving.
# - **Career Growth:** Continuous learning opportunities through workshops, training sessions, and practical experience with Claude.
#
# Explore our **open roles** and embark on a career where your work makes a difference in the evolving landscape of AI!
#
# ---
#
# ## Connect with Us
#
# Ready to explore the world of AI with Anthropic? Visit our website to learn more about our products, insights, and opportunities to partner with us.
#
# - **Website:** [Claude.ai](https://www.claude.ai)
# - **Follow Us:** Stay updated on our latest research and developments through our newsletters and announcements.
#
# ---
#
# **Contact us today and let’s build a safer AI future together!**

# %%
# Try changing the system prompt to the humorous version when you make the Brochure for Hugging Face:

stream_brochure("HuggingFace", "https://huggingface.co")

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../business.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#181;">Business applications</h2>
#             <span style="color:#181;">In this exercise we extended the Day 1 code to make multiple LLM calls, and generate a document.
#
# This is perhaps the first example of Agentic AI design patterns, as we combined multiple calls to LLMs. This will feature more in Week 2, and then we will return to Agentic AI in a big way in Week 8 when we build a fully autonomous Agent solution.
#
# Generating content in this way is one of the very most common Use Cases. As with summarization, this can be applied to any business vertical. Write marketing content, generate a product tutorial from a spec, create personalized email content, and so much more. Explore how you can apply content generation to your business, and try making yourself a proof-of-concept prototype. See what other students have done in the community-contributions folder -- so many valuable projects -- it's wild!</span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Before you move to Week 2 (which is tons of fun)</h2>
#             <span style="color:#900;">Please see the week1 EXERCISE notebook for your challenge for the end of week 1. This will give you some essential practice working with Frontier APIs, and prepare you well for Week 2.</span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../resources.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#f71;">A reminder on 3 useful resources</h2>
#             <span style="color:#f71;">1. The resources for the course are available <a href="https://edwarddonner.com/2024/11/13/llm-engineering-resources/">here.</a><br/>
#             2. I'm on LinkedIn <a href="https://www.linkedin.com/in/eddonner/">here</a> and I love connecting with people taking the course!<br/>
#             3. I'm trying out X/Twitter and I'm at <a href="https://x.com/edwarddonner">@edwarddonner<a> and hoping people will teach me how it's done..
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../thankyou.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#090;">Finally! I have a special request for you</h2>
#             <span style="color:#090;">
#                 My editor tells me that it makes a MASSIVE difference when students rate this course on Udemy - it's one of the main ways that Udemy decides whether to show it to others. If you're able to take a minute to rate this, I'd be so very grateful! And regardless - always please reach out to me at ed@edwarddonner.com if I can help at any point.
#             </span>
#         </td>
#     </tr>
# </table>
